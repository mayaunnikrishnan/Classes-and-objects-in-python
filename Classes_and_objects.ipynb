# %% [markdown]
# # **Classes and Objects:**
#
# [A class is a user-defined blueprint or prototype from which objects are created.
# Classes are created by keyword class.
# Attributes are the variables that belong to a class.
# Attributes are always public and can be accessed using the dot (.) operator.]
#
#
# Imagine you're the headmaster of a magical school called "Fantastic School of Wizards." In this school, you have a special book called "Student Enrollments," and you use it to create new student profiles.
#
# **Class**: Student
#
# In the book, you have a page called "Student Class." This page tells you what every student can have and do. Like, every student should have a name and an age. They can study spells and potions, and they can also play magical games.
#
# **Object**: Student
#
# [An object consists of :
#
# **State**: It is represented by the attributes of an object. It also reflects the properties of an object.
#
# **Behaviour**: It is represented by the methods of an object. It also reflects the response of an object to other
# objects.
#
# **Identity**: It gives a unique name to an object and enables one object to interact with other objects.]
#
# Now, whenever you enroll a new student, you create a special profile for them based on what's written in the "Student Class" page. So, each student you enroll becomes a real student in your school.

# %%
class Student:
    name= "Ajmal"
    Roll_no=10
    Course="Python"
    def reading(self):
        print("reading")
    def coding(self,language):
        print(f"coding in {language}")

# %%
student1=Student()
print(student1.name)
student1.reading()
student1.coding("Java")
# Out:
# Ajmal
# reading
# coding in Java

# %%
class Student:
    def __init__(self,course):
        self.name="Ajmal"
        self.Roll_no=10
        self.Course=course
    def reading(self):
        print("reading")
    def coding(self):
        print("coding",self.Course)
student2=Student("Java")
student2.coding()
# Out:
# coding Java

# %%
# This is our class or the "Student Class" page
class Student:
    def __init__(self, name, age):
        self.name = name  # Every student has a name
        self.age = age  # And an age

    def study(self, subject):
        print(self.name, "is studying", subject)

    def play(self, game):
        print(self.name, "is playing", game)

# %%
# These are objects or real students
harry = Student("Harry Potter", 11)
hermione = Student("Hermione Granger", 11)
ron = Student("Ron Weasley", 11)

# %%
# Now let's see what our students can do!
harry.study("Spells")
hermione.play("Wizard's Chess")
ron.study("Potions")
# Out:
# Harry Potter is studying Spells
# Hermione Granger is playing Wizard's Chess
# Ron Weasley is studying Potions

# %% [markdown]
# ## **__init__() method:**
#
# [All classes have a function called __init__(), which is always executed when the class is being initiated.]
#
# Okay, so you know how we have our magical school with all these students, right? Well, let's talk about how each student gets their special traits when they join our school.
#
# Think of the __init__() function as a magical spell that happens as soon as a new student arrives at our school. It's like a welcoming ceremony where we give the student some cool things right from the start.
#
# Magic Explanation:
#
# When a new student arrives, we do this special spell called __init__(). This spell is like a recipe that makes sure every student gets their name and age, which are like their own magical tokens. This way, we know who they are and how old they are as soon as they step into our school.

# %% [markdown]
# ## **Object Methods:**
#
# [Objects can also contain methods. Methods in objects are functions that belong to the object.]
#
# Alright, let's dive into the magical abilities our students have in our school. You know how students in our school can do different things like study spells and play games? Well, we can think of these actions as special powers that each student has. We call these special powers "object methods."
#
# Magic Explanation:
#
# So, you remember that each student is like a real person in our school, right? And just like how you can do things like read, draw, and play, our students can also do their own special things.
#
# For example, Harry can study spells, Hermione can play Wizard's Chess, and Ron can study potions. These things they can do are their "object methods." It's like they have a bunch of magic spells they can cast anytime they want!

# %% [markdown]
# ## **The self Parameter:**
#
# [The self parameter is a reference to the current instance of the class, and is used to access variables that belongs to the class.]
#
# "self" is like a magic word that helps each student talk about themselves when they're using their special powers. Just like when you say "I" to tell everyone that you're the one doing something amazing!

# %% [markdown]
# Imagine each student has their own special notebook where they can write things down. These things are like their own secrets and stories. And you know how some things are special to just one student, and other things are shared by all students? That's where local and class things come in!
#
# **Local Variables**:
#
# These are like secret notes that only one student can read. Let's say Hermione writes "My favorite spell" in her notebook. Nobody else can see it because it's her secret. These are local notes just for her.
#
# **Instance Methods**:
#
# These are like special magic spells that only a particular student can use. When Harry does his "study" spell, it's his special spell that only he knows. And when Hermione uses her "play" spell, it's her own magic. These spells are just for them.
#
# **Class Attributes**:
#
#  These are like things that are the same for all students in our school. Imagine we have a big magical tree in our schoolyard. Every student can see it and play near it. That tree is like a class attribute—it's something everyone knows about.
#
# **Instance Variables**:
#
#  These are like personal things each student has that they can share with others. Ron might have a favorite magical creature he talks about. He can tell others about it, and they'll know about his magical creature. These are like personal belongings they share.

# %%
# This is our class or the "Student Class" page
class Student:
    school_name = "Fantastic School of Wizards"  # Class attribute for everyone

    def __init__(self, name, age):
        self.name = name
        self.age = age
        self.notebook = []  # Instance variable, like their special notebook

    def study(self, subject):
        print(self.name, "is studying", subject)  # Instance method

    def play(self, game):
        print(self.name, "is playing", game)  # Instance method

    def write_note(self, note):
        self.notebook.append(note)  # Instance method to write in their notebook

# %%
# These are objects or real students
harry = Student("Harry Potter", 11)
hermione = Student("Hermione Granger", 11)
ron = Student("Ron Weasley", 11)

# %%
# Now let's see their magical things in action!
print(harry.school_name)  # Everyone knows about the school name
print(hermione.school_name)
# Out:
# Fantastic School of Wizards
# Fantastic School of Wizards

# %%
harry.study("Spells")  # Harry's special spell
hermione.play("Wizard's Chess")  # Hermione's special spell
# Out:
# Harry Potter is studying Spells
# Hermione Granger is playing Wizard's Chess

# %%
harry.write_note("I found a secret passage!")  # Harry's secret note
hermione.write_note("My favorite spell is Lumos!")  # Hermione's secret note

# %%
print(harry.notebook)  # Harry's notes
print(hermione.notebook)  # Hermione's notes
# Out:
# ['I found a secret passage!']
# ['My favorite spell is Lumos!']

# %% [markdown]
# ## **For practice:**
#
# ![pic3.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![pic5.jpg](data:image/jpeg;base64,...)

# %%
class TemperatureConverter:
    def celsius_to_fahrenheit(self, celsius):
        return (celsius * 9/5) + 32

# Example usage
converter = TemperatureConverter()
temperature_celsius = 25
temperature_fahrenheit = converter.celsius_to_fahrenheit(temperature_celsius)
print(f"{temperature_celsius}°C is {temperature_fahrenheit}°F")
# Out:
# 25°C is 77.0°F

# %%
class CircleCalculator:
    def calculate_area(self, radius):
        return 3.14159 * radius**2

# Example usage
calculator = CircleCalculator()
radius = 5
area = calculator.calculate_area(radius)
print(f"The area of the circle with radius {radius} is {area:.2f}")
# Out:
# The area of the circle with radius 5 is 78.54

# %%
class NameInitials:
    def get_initials(self, full_name):
        names = full_name.split()
        initials = [name[0].upper() for name in names]
        return ''.join(initials)

# Example usage
initials_generator = NameInitials()
full_name = "John Doe"
initials = initials_generator.get_initials(full_name)
print(f"The initials of '{full_name}' are '{initials}'")
# Out:
# The initials of 'John Doe' are 'JD'

# %%
class StringReverser:
    def reverse_string(self, text):
        return text[::-1]

# Example usage
reverser = StringReverser()
text = "Hello, world!"
reversed_text = reverser.reverse_string(text)
print(f"The reversed text is: '{reversed_text}'")
# Out:
# The reversed text is: '!dlrow ,olleH'

# %%
class NumberChecker:
    def is_even(self, number):
        return number % 2 == 0

# Example usage
checker = NumberChecker()
number = 10
if checker.is_even(number):
    print(f"{number} is even")
else:
    print(f"{number} is not even")
# Out:
# 10 is even

# %% [markdown]
# ## **Constructors in Python**
# init() method is called the constructor and is always called when an object is created.
#
# type of constructors:
#
# @ default constructor: constructor which dosen't accept any arguments
#
# @ parameterless constructor: constuctor without parameter
#
# @ parameterised constructor: constuctor with parameter

# %%
#Default Constructor Example:
class Dog:
    pass  # No constructor defined

# Creating a Dog object (uses the default constructor)
dog_instance = Dog()

# %%
#Parameterless Constructor Example:
class Cat:
    def __init__(self):
        print("A cat is born without a name.")

# Creating a Cat object (uses the parameterless constructor)
cat_instance = Cat()
# Out:
# A cat is born without a name.

# %%
#Parameterized Constructor:
class Person:
    # Parameterized constructor
    def __init__(self, name, age):
        self.name = name
        self.age = age
        print(f"A person named {self.name} is born. Age: {self.age}")

person_instance = Person("Alice", 30)
# Out:
# A person named Alice is born. Age: 30

# %% [markdown]
# ## **Destructors in Python**
# Destructors are called when an object gets destroyed
#
# The del() method is a known as a destructor method in Python.
#
# Destructors are not much needed in python because Python has a garbage collector that handles memory
# management automatically.

# %%
class Book:
    def __init__(self, title):
        self.title = title
        print(f"Book '{self.title}' is created.")

    def __del__(self):
        print(f"Book '{self.title}' is being destroyed.")

# Creating Book objects
book1 = Book("Harry Potter and the Sorcerer's Stone")
book2 = Book("The Lord of the Rings")

# Deleting one of the Book objects
del book1

# The program exits, causing the remaining objects to be destroyed
# Out:
# Book 'Harry Potter and the Sorcerer's Stone' is created.
# Book 'The Lord of the Rings' is created.
# Book 'Harry Potter and the Sorcerer's Stone' is being destroyed.

# %% [markdown]
# ![Picture1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Picture2.jpg](data:image/jpeg;base64,...)

# %%
class Student:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def display(self):
        print(f"Name: {self.name}\nAge: {self.age}")

# Example usage
student1 = Student("Alice", 20)
student1.display()

# %%
class Rectangle:
    def __init__(self, width, height):
        self.width = width
        self.height = height

    def calculate_area(self):
        return self.width * self.height

    def calculate_perimeter(self):
        return 2 * (self.width + self.height)

# Example usage
rectangle = Rectangle(5, 8)
print("Area:", rectangle.calculate_area())
print("Perimeter:", rectangle.calculate_perimeter())

# %%
class BankAccount:
    def __init__(self, account_number, balance):
        self.account_number = account_number
        self.balance = balance

    def deposit(self, amount):
        self.balance += amount

    def withdraw(self, amount):
        if self.balance >= amount:
            self.balance -= amount
        else:
            print("Insufficient balance")

    def display(self):
        print(f"Account Number: {self.account_number}\nBalance: {self.balance}")

# Example usage
account = BankAccount("12345", 1000)
account.deposit(500)
account.withdraw(200)
account.display()

# %%
class Book:
    def __init__(self, title, author, year):
        self.title = title
        self.author = author
        self.year = year

    def display(self):
        print(f"Title: {self.title}\nAuthor: {self.author}\nYear: {self.year}")

# Example usage
book = Book("The Catcher in the Rye", "J.D. Salinger", 1951)
book.display()

# %%
class BankCustomer:
    def __init__(self, name, account_number, balance):
        self.name = name
        self.account_number = account_number
        self.balance = balance

    def deposit(self, amount):
        self.balance += amount

    def withdraw(self, amount):
        if self.balance >= amount:
            self.balance -= amount
        else:
            print("Insufficient balance")

    def display(self):
        print(f"Name: {self.name}\nAccount Number: {self.account_number}\nBalance: {self.balance}")

# Example usage
customer = BankCustomer("John Doe", "98765", 1500)
customer.deposit(300)
customer.withdraw(200)
customer.display()

# %%
# creating  a simple claculator class
class Calculator:
    def add(self, a, b):
        return a + b

    def subtract(self, a, b):
        return a - b

    def multiply(self, a, b):
        return a * b

    def divide(self, a, b):
        if b == 0:
            return "Cannot divide by zero"
        return a / b

# Creating an instance of the Calculator class
calculator = Calculator()

# Performing calculations
result_add = calculator.add(5, 3)         # 5 + 3 = 8
result_subtract = calculator.subtract(8, 2)  # 8 - 2 = 6
result_multiply = calculator.multiply(4, 6)  # 4 * 6 = 24
result_divide = calculator.divide(10, 2)    # 10 / 2 = 5

# Displaying results
print("Addition:", result_add)
print("Subtraction:", result_subtract)
print("Multiplication:", result_multiply)
print("Division:", result_divide)
# Out:
# Addition: 8
# Subtraction: 6
# Multiplication: 24
# Division: 5.0

# %% [markdown]
# ## **Inheritance in Python**
# capability of one class to derive or inherit the properties from another class.
#
# Benefits of inheritance are:
#
# @ real-world relationships
#
# @ reusability of a code
#
# @ add more features to a class without modifying it
#
# @ transitive in nature, which means that if class B inherits from another class A, then all the subclasses of
# B would automatically inherit from class A.
#
# **Creating a Parent Class/Super class/Base class**
#
# Parent class is the class being inherited from,also called base class.
# Any class can be a parent class, so the syntax is same as that of creating a class.
#
#
# **Creating a Child Class/sub class**
#
# Python Inheritance Syntax
#
#
#
# ```
# Class BaseClass:
#      {Body}
# Class DerivedClass(BaseClass):
#       {Body}
# ```

# %% [markdown]
# ### **Different types of Inheritance:**
# @ **Single inheritance**: When a child class inherits from only one parent class, it is called single inheritance.
#
# @ **Multiple inheritances**: When a child class inherits from multiple parent classes, it is called multiple
# inheritances.
#
# @ **Multilevel Inheritance** :features of the base class and the derived class are further inherited into the new
# derived class.
#
# @ **Hierarchical Inheritance**: When more than one derived class are created from a single base class
#
# @ **Hybrid Inheritance**: Inheritance consisting of multiple types of inheritance is called hybrid inheritance.

# %%
# single inheritance
class parent:
   def display(self):
      print("im a parent class")
class child(parent):
   def show(self):
      print("im a child class")
c=child()
c.display()
c.show()
# Out:
# im a parent class
# im a child class

# %%
# multiple inheritance
class Father:
    def display(self):
        print("I'm father class")

class Mother:
    def display2(self):
        print("I'm a mother class")

class Child(Father, Mother):
    def show(self):
        print("I'm a child class")

# Creating an instance of the Child class
c = Child()

# Calling methods
c.display()   # Output: I'm father class
c.display2()  # Output: I'm a mother class
c.show()      # Output: I'm a child class
# Out:
# I'm father class
# I'm a mother class
# I'm a child class

# %%
#multilevel inheritance
class Grandpa:
    def greatdisplay(self):
        print("I'm grandpa class")

class Father(Grandpa):
    def display(self):
        print("I'm father class")

class Child(Father):
    def show(self):
        print("I'm child class")

c = Child()
c.greatdisplay()  # Output: I'm grandpa class
# Out:
# I'm grandpa class

# %%
# heirarchial inheritance
class Father:
    def display(self):
        print("I'm father class")

class Boy(Father):
    def show1(self):
        print("I'm boy child class")

class Girl(Father):
    def show2(self):
        print("I'm girl child class")

b = Boy()
g = Girl()
b.display()  # Output: I'm father class
# Out:
# I'm father class

# %%
# hybrid inheritance
class Grandpa:
    def greatdisplay(self):
        print("I'm great grandfather class")

class Father(Grandpa):
    def display1(self):
        print("I'm father class")

class Mother(Grandpa):
    def display2(self):
        print("I'm mother class")

class Child(Father, Mother):
    def show(self):
        print("I'm a child class")

c = Child()
c.greatdisplay()  # Output: I'm great grandfather class
c.display1()      # Output: I'm father class
c.display2()      # Output: I'm mother class
c.show()          # Output: I'm a child class
# Out:
# I'm great grandfather class
# I'm father class
# I'm mother class
# I'm a child class

# %% [markdown]
# ## **Encapsulation in Python**
# Encapsulation is one of the fundamental concepts in object-oriented programming (OOP).
# It describes the
# idea of wrapping data and the methods that work on data within one unit. This puts restrictions on
# accessing variables and methods directly and can prevent the accidental modification of data.
#
# **Protected members**
#
# Protected members are those members of the class that cannot be accessed outside the class but can be
# accessed from within the class and its subclasses
#
# **Private members**
#
# Private members are similar to protected members, the difference is that the class members declared
# private should neither be accessed outside the class nor by any base class
#
# **Protected members of Parent class**
#
# Although the protected variable can be accessed out of the class as well as in the derived class(modified
# too in derived class), it is customary(convention not a rule) to not access the protected out the class body

# %%
class Parent:
    def display(self):
        self.__a = 2
        print("I'm a parent class")
        print("Parent protected 'a' is", self.__a)

class Child(Parent):
    def show(self):
        print("I'm a child class")
        self.__a = 3  # Modifying the protected member of the parent class
        print("Child protected 'a' is", self.__a)

# %%
c = Child()
c.show()
c.display()
# Out:
# I'm a child class
# Child protected 'a' is 3
# I'm a parent class
# Parent protected 'a' is 2

# %%
p = Parent()
p.display()
# Out:
# I'm a parent class
# Parent protected 'a' is 2

# %%
# Protected member of the parent class cannot be accessed directly by the child class
# The following line will result in an AttributeError:
# print(c.__a)

# %% [markdown]
# **Private members of the parent class**
#
# We can make an instance variable private by adding double underscores before its name,which won’t be
# available to the child class, Also we can make method private by adding double underscore before it

# %%
class Parent:
    def display(self, name, age):
        self.name = name
        self.__age = age
        print("I'm a parent class")
        print("Father's name is", self.name)
        print("Father's age is", self.__age)

class Child(Parent):
    def show(self):
        print("I'm a child class")

# %%
c = Child()
p = Parent()

# %%
c.show()  # Output: I'm a child class
# Out:
# I'm a child class

# %%
# Calling the display method with arguments
c.display("Rajesh", 46)  # Output: I'm a parent class, Father's name is Rajesh, Father's age is 46
# Out:
# I'm a parent class
# Father's name is Rajesh
# Father's age is 46

# %%
# The following lines will result in AttributeError because '__age' is a private attribute of Parent
#print(c.name)
# print(c.__age)

# %% [markdown]
# ## **Polymorphism in Python**
#
# Polymorphism is a fundamental concept in object-oriented programming that allows objects of different classes to be treated as objects of a common superclass. It enables you to write code that can work with objects of different types in a unified way.
#
# **There are two main types of polymorphism**:
#
# compile-time (**method overloading**)
#
# runtime (**method overriding**).
#
# ### Compile-Time Polymorphism (Method Overloading):
#
# In some programming languages (but not in Python), you can define multiple methods with the same name but different parameter lists. This is known as method overloading. Python doesn't support method overloading in the traditional sense.
#
# ### Runtime Polymorphism (Method Overriding):
# This is the more common form of polymorphism in Python. It involves overriding a method in a derived class to provide a specific implementation while maintaining the method signature of the base class.

# %%
#example demonstrating a form of compile-time polymorphism in Python:
class Calculator:
    def add(self, a, b=None):
        if b is None:
            return a
        else:
            return a + b

# Creating an instance of Calculator
calc = Calculator()

# Using the add method with different arguments
result1 = calc.add(5)
result2 = calc.add(5, 10)

print(result1)  # Output: 5
print(result2)  # Output: 15
# Out:
# 5
# 15

# %% [markdown]
# In this example, the add method in the Calculator class can accept one or two arguments. If only one argument is provided, it returns that value. If two arguments are provided, it returns their sum. This demonstrates a form of compile-time polymorphism, where the behavior of the method varies based on the number of arguments passed to it.

# %%
#example of method overriding (runtime polymorphism) in Python:
class Animal:
    def make_sound(self):
        pass  # Abstract method, to be overridden in subclasses

class Dog(Animal):
    def make_sound(self):
        return "Woof!"

class Cat(Animal):
    def make_sound(self):
        return "Meow!"

# Polymorphism in action
def animal_sound(animal):
    return animal.make_sound()

# Creating instances
dog = Dog()
cat = Cat()

# Using the same function for different objects
print(animal_sound(dog))  # Output: Woof!
print(animal_sound(cat))  # Output: Meow!
# Out:
# Woof!
# Meow!

# %% [markdown]
# In this example:
#
# Animal is the base class with an abstract method make_sound, which
# should be overridden in subclasses.
#
# Dog and Cat are derived classes that override the make_sound method to provide their own implementations.
#
# The function animal_sound takes an instance of Animal (or any subclass) and calls its make_sound method.
#
# This demonstrates polymorphism, where the same function is used with different types of objects, resulting in different behavior based on their individual implementations.
#
# In summary, polymorphism allows you to write more flexible and reusable code by treating different objects in a unified manner, even if they belong to different classes.

# %% [markdown]
# ## **Abstarctmethod**
#
# @ **Abstact class**: which have abstact methods
#
# @ **Abstract method**: method with declaration not the definition
# object cannot be instantiated for abstract class
#
# @**Concrete class**: class without abstact method
# object can only be instantiated for concete class

# %%
from abc import ABC, abstractmethod

class MyAbstractClass(ABC):
    @abstractmethod
    def display(self):
        pass

    @abstractmethod
    def show(self):
        pass

class Demo1(MyAbstractClass):
    def display(self):
        print("Display method in Demo1")

class Demo2(MyAbstractClass):
    def display(self):
        print("Display method in Demo2")

    def show(self):
        print("Show method in Demo2")

d2 = Demo2()
d2.display()
d2.show()
# Out:
# Display method in Demo2
# Show method in Demo2

# %% [markdown]
# In this corrected code:
#
# ABC and abstractmethod are imported from the abc module. The ABC class is used as a base class for creating abstract base classes, and the abstractmethod decorator is used to define abstract methods.
#
# MyAbstractClass is defined as an abstract base class with abstract methods display and show.
#
# Demo1 and Demo2 are concrete classes that inherit from MyAbstractClass.
#
# Demo1 provides an implementation for the display method, while Demo2 provides implementations for both the display and show methods.

# %% [markdown]
# ### **ClassMethod:**
#
# @ works according to the state of class
#
# @ it takes 'cls' as argument
#
# @ it uses '@classmethod' decorator
#
#
#
# ### **StaticMethod:**
#
# @ it is like utility that donot work according to the class
#
#
# @ no any specific argument
#
# @ it uses '@classmethod'decorator

# %%
class Methods:
    def normal_method(self):
        print("Normal method")

    @classmethod
    def class_method(cls):
        print("I'm a class method")

    @staticmethod
    def static_method():
        print("I'm a static method")

# Creating an instance of the class
obj = Methods()

# Calling instance method
obj.normal_method()  # Output: Normal method

# Calling class method using the class name
Methods.class_method()  # Output: I'm a class method

# Calling static method using the class name
Methods.static_method()  # Output: I'm a static method
# Out:
# Normal method
# I'm a class method
# I'm a static method

# %% [markdown]
# In this code:
#
# Methods is the class you've defined.
#
# normal_method is a regular instance method that requires an instance of the class to be called.
#
# class_method is a class method that uses the @classmethod decorator. It takes the class (cls) as its first parameter and can be called using the class name.
#
# static_method is a static method that uses the @staticmethod decorator. It doesn't require access to the instance or class and can be called using the class name.

# %% [markdown]
# #Magical Methods in Python
# **Overview**
#
# Magical methods, also known as "dunder" (double underscore) methods, are special methods in Python that have double underscores at the beginning and end of their names (e.g., __init__, __str__). These methods allow you to define how objects of your class behave with built-in functions and operators. They are a key part of making your custom classes integrate smoothly with Python’s syntax and operations.
#
# **Common Magical Methods**
#
# Here are some of the most commonly used magical methods:
#
# **Object Initialization and Representation**
#
# __init__(self, ...): This method is called when an instance of the class is created. It initializes the object's attributes.

# %%
class MyClass:
    def __init__(self, value):
        self.value = value

obj = MyClass(42)
print(obj.value)  # Output: 42
# Out:
# 42

# %% [markdown]
# `__str__(self)`:
#
# This method is called by the str() function and the print statement to get a string representation of the object.

# %%
class MyClass:
    def __str__(self):
        return f'MyClass with value: {self.value}'

# %% [markdown]
# `__repr__(self)`:
#
# This method is called by the repr() function and is used to get a detailed string representation of the object, often one that could be used to recreate the object.

# %%
class MyClass:
    def __repr__(self):
        return f'MyClass({self.value})'

# %% [markdown]
# ##Arithmetic Operations
# `__add__(self, other)`:
#
# This method is called to implement the addition operator (+).

# %%
class MyClass:
    def __init__(self, value):
        self.value = value

    def __add__(self, other):
        return MyClass(self.value + other.value)

# %% [markdown]
# `__sub__(self, other`):
#
# This method is called to implement the subtraction operator (-).

# %%
class MyClass:
    def __sub__(self, other):
        return MyClass(self.value - other.value)

# %% [markdown]
# `__mul__(self, other)`:
#
# This method is called to implement the multiplication operator (*).

# %%
class MyClass:
    def __mul__(self, other):
        return MyClass(self.value * other.value)

# %% [markdown]
# ##Comparison Operations
# `__eq__(self, other)`:
#
# This method is called to implement the equality operator (==).

# %%
class MyClass:
    def __eq__(self, other):
        return self.value == other.value

# %% [markdown]
# `__lt__(self, other)`:
#
# This method is called to implement the less than operator (<).

# %%
class MyClass:
    def __lt__(self, other):
        return self.value < other.value

# %% [markdown]
# `__gt__(self, other)`:
#
# This method is called to implement the greater than operator (>).

# %%
class MyClass:
    def __gt__(self, other):
        return self.value > other.value

# %% [markdown]
# ##Container Emulation
# `__len__(self)`:
#
# This method is called by the len() function to get the length of the container.

# %%
class MyContainer:
    def __init__(self, items):
        self.items = items

    def __len__(self):
        return len(self.items)

# %% [markdown]
# `__getitem__(self, key)`:
#
# This method is called to retrieve an item using the subscript notation (obj[key]).

# %%
class MyContainer:
    def __getitem__(self, key):
        return self.items[key]

# %% [markdown]
# `__setitem__(self, key, value)`:
#
# This method is called to set an item using the subscript notation (obj[key] = value).

# %%
class MyContainer:
    def __setitem__(self, key, value):
        self.items[key] = value

# %% [markdown]
# `__delitem__(self, key)`:
#
# This method is called to delete an item using the subscript notation (del obj[key]).

# %%
class MyContainer:
    def __delitem__(self, key):
        del self.items[key]

# %% [markdown]
# ##Context Management
# `__enter__(self)`:
#
# This method is called when the execution enters the context of the with statement.

# %%
class MyResource:
    def __enter__(self):
        print("Entering context")
        return self

# %% [markdown]
# `__exit__(self, exc_type, exc_value, traceback)`:
#
# This method is called when the execution leaves the context of the with statement.

# %%
class MyResource:
    def __exit__(self, exc_type, exc_value, traceback):
        print("Exiting context")

# %% [markdown]
# ##Callable Objects
# `__call__(self, ...)`:
#
# This method allows an instance of the class to be called as a function

# %%
class MyCallable:
    def __call__(self, *args, **kwargs):
        print("Called with", args, kwargs)
